# %% [markdown]
# <div align="right" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img
#  src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/alx-courses/aice/assets/Content_page_banner_blue_dots.png"
#  alt="ALX Content Header"
#  class="full-width-image"
# />
# </div>

# %% [markdown]
# # Subquery in  WHERE

# %% [markdown]
# In this notebook, we delve deeper into subqueries, specifically subqueries within a WHERE clause. One of the powerful aspects of subqueries is their ability to compare individual rows with aggregated data. This concept will be explored here.

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning objectives
#
# In this train, we will learn:
# - How to use the WHERE clause in subqueries.
# - How to join tables.

# %% [markdown]
# ## Connecting to our MySQL database
#
# Using our `Access_to_Basic_Services` table in our `united_nations` database we created in MySQL Workbench, we want to answer some questions about our dataset. We can apply the same queries we used in MySQL Workbench in this notebook if we connect to our MySQL server by running the cells below.
#
# Note that before this tutorial, we will already have worked through the lessons where the `united_nations.Basic_Services` table, `united_nations.Economic_Indicators` table, and `united_nations.Geographic_Locations` table were created.

# %%
# Load and activate the SQL extension to allow us to execute SQL in a Jupyter notebook. 
# If you get an error here, make sure that mysql and pymysql are installed correctly. 

# %load_ext sql

# %%
# Establish a connection to the local database using the '%sql' magic command.
# Replace 'password' with our connection password and `db_name` with our database name. 
# If you get an error here, please make sure the database name or password is correct.

# %sql mysql+pymysql://root:Mysql.003@localhost:3306/united_nations

# %% [markdown]
# To make a query, we add the `%%sql` command to the start of a cell, create one open line then the query like below, and run the cell.

# %%
# %%sql
#
# SELECT
#     *
# FROM
#     Access_to_Basic_Services
# LIMIT 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2015, 94.67, Decimal('98.00'), Decimal('17.542806'), Decimal('184.39'), Decimal('2699700.00'), Decimal('4.93')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2016, 94.67, Decimal('98.00'), Decimal('17.794055'), Decimal('137.28'), Decimal('2699700.00'), Decimal('4.96')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2017, 95.0, Decimal('98.00'), Decimal('18.037776'), Decimal('166.81'), Decimal('2699700.00'), Decimal('4.90')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2018, 95.0, Decimal('98.00'), Decimal('18.276452'), Decimal('179.34'), Decimal('2699700.00'), Decimal('4.85')),
#  ('Central and Southern Asia', 'Central Asia', 'Kazakhstan', 2019, 95.0, Decimal('98.00'), Decimal('18.513673'), Decimal('181.67'), Decimal('2699700.00'), Decimal('4.80'))]

# %%
# %%sql
# DESCRIBE Access_to_Basic_Services;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 10 rows affected.
# [('Region', 'varchar(32)', 'YES', '', None, ''),
#  ('Sub_region', 'varchar(25)', 'YES', '', None, ''),
#  ('Country_name', 'varchar(37)', 'NO', '', None, ''),
#  ('Time_period', 'int(11)', 'NO', '', None, ''),
#  ('Pct_access_to_water', 'float', 'YES', '', None, ''),
#  ('Pct_managed_sanitation_services', 'decimal(5,2)', 'YES', '', None, ''),
#  ('Est_population_in_millions', 'decimal(11,6)', 'YES', '', None, ''),
#  ('Est_gdp_in_billions', 'decimal(8,2)', 'YES', '', None, ''),
#  ('Land_area', 'decimal(10,2)', 'YES', '', None, ''),
#  ('Pct_unemployment', 'decimal(5,2)', 'YES', '', None, '')]

# %%
# %%sql
# DESCRIBE Economic_Indicators;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 5 rows affected.
# [('Country_name', 'varchar(37)', 'NO', 'PRI', None, ''),
#  ('Time_period', 'int(11)', 'NO', 'PRI', None, ''),
#  ('Est_gdp_in_billions', 'decimal(8,2)', 'YES', '', None, ''),
#  ('Est_population_in_millions', 'decimal(11,6)', 'YES', '', None, ''),
#  ('Pct_unemployment', 'decimal(5,2)', 'YES', '', None, '')]

# %% [markdown]
# ## Exercise

# %% [markdown]
# We want to answer the following question:
#
# For the year 2020, which countries have a GDP above the global average, but still have less than 90% of their population with access to managed drinking water services?
#
# This question will shed light on nations that, despite having a robust economy, may still be facing challenges in providing basic amenities like water.

# %% [markdown]
# ### Task 1
#
# Start by constructing a query that displays the average GDP of a country during the year 2020.

# %%
# %%sql
# # Add your code here
# SELECT
#     Country_name,
#     AVG(Est_gdp_in_billions) AS Avg_GDP
# FROM Access_to_Basic_Services
# WHERE Time_period = 2020
# GROUP BY Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 165 rows affected.
# [('Afghanistan', Decimal('20.140000')),
#  ('Algeria', Decimal('145.010000')),
#  ('American Samoa', Decimal('0.720000')),
#  ('Angola', Decimal('53.620000')),
#  ('Argentina', Decimal('385.540000')),
#  ('Armenia', Decimal('12.640000')),
#  ('Australia', Decimal('1326.900000')),
#  ('Azerbaijan', Decimal('42.690000')),
#  ('Bahrain', Decimal('34.720000')),
#  ('Bangladesh', Decimal('373.900000')),
#  ('Barbados', Decimal('4.670000')),
#  ('Belize', Decimal('2.080000')),
#  ('Benin', Decimal('15.650000')),
#  ('Bermuda', Decimal('6.890000')),
#  ('Bhutan', Decimal('2.330000')),
#  ('Bolivia (Plurinational State of)', None),
#  ('Botswana', Decimal('14.930000')),
#  ('Brazil', Decimal('1448.560000')),
#  ('British Virgin Islands', None),
#  ('Brunei Darussalam', Decimal('12.010000')),
#  ('Burkina Faso', Decimal('17.930000')),
#  ('Burundi', Decimal('2.650000')),
#  ('Cabo Verde', Decimal('1.700000')),
#  ('Cambodia', Decimal('25.870000')),
#  ('Cameroon', Decimal('40.770000')),
#  ('Canada', Decimal('1645.420000')),
#  ('Central African Republic', Decimal('2.330000')),
#  ('Chad', Decimal('10.720000')),
#  ('Chile', Decimal('252.730000')),
#  ('China', Decimal('14687.670000')),
#  ('Colombia', Decimal('270.300000')),
#  ('Congo', None),
#  ('Cook Islands', None),
#  ('Costa Rica', Decimal('62.160000')),
#  ("Côte d'Ivoire", None),
#  ('Cuba', Decimal('107.350000')),
#  ('Cyprus', Decimal('25.010000')),
#  ("Democratic People's Republic of Korea", None),
#  ('Democratic Republic of the Congo', None),
#  ('Djibouti', Decimal('3.180000')),
#  ('Dominican Republic', Decimal('78.840000')),
#  ('Ecuador', Decimal('99.290000')),
#  ('Egypt', None),
#  ('El Salvador', Decimal('24.560000')),
#  ('Eswatini', Decimal('3.980000')),
#  ('Ethiopia', Decimal('107.660000')),
#  ('Falkland Islands (Malvinas)', None),
#  ('Fiji', Decimal('4.480000')),
#  ('French Guiana', None),
#  ('French Polynesia', Decimal('5.710000')),
#  ('Gabon', Decimal('15.310000')),
#  ('Gambia', None),
#  ('Georgia', Decimal('15.840000')),
#  ('Ghana', Decimal('70.040000')),
#  ('Greenland', Decimal('3.080000')),
#  ('Guadeloupe', None),
#  ('Guam', Decimal('5.890000')),
#  ('Guatemala', Decimal('77.630000')),
#  ('Guinea', Decimal('14.180000')),
#  ('Guinea-Bissau', Decimal('1.430000')),
#  ('Guyana', Decimal('5.470000')),
#  ('Haiti', Decimal('14.510000')),
#  ('Honduras', Decimal('23.830000')),
#  ('India', Decimal('2667.690000')),
#  ('Indonesia', Decimal('1058.690000')),
#  ('Iran (Islamic Republic of)', None),
#  ('Iraq', Decimal('184.370000')),
#  ('Israel', Decimal('413.270000')),
#  ('Jamaica', Decimal('13.810000')),
#  ('Japan', Decimal('5040.110000')),
#  ('Jordan', Decimal('44.180000')),
#  ('Kazakhstan', Decimal('171.080000')),
#  ('Kenya', Decimal('100.670000')),
#  ('Kiribati', Decimal('0.180000')),
#  ('Kuwait', Decimal('105.960000')),
#  ('Kyrgyzstan', None),
#  ("Lao People's Democratic Republic", None),
#  ('Lebanon', Decimal('31.710000')),
#  ('Lesotho', Decimal('2.230000')),
#  ('Liberia', Decimal('3.040000')),
#  ('Libya', Decimal('50.360000')),
#  ('Madagascar', Decimal('13.050000')),
#  ('Malawi', Decimal('12.180000')),
#  ('Malaysia', Decimal('337.340000')),
#  ('Maldives', Decimal('3.750000')),
#  ('Mali', Decimal('17.470000')),
#  ('Marshall Islands', Decimal('0.240000')),
#  ('Martinique', None),
#  ('Mauritania', Decimal('8.410000')),
#  ('Mauritius', Decimal('11.400000')),
#  ('Mayotte', None),
#  ('Mexico', Decimal('1090.520000')),
#  ('Mongolia', Decimal('13.310000')),
#  ('Montserrat', None),
#  ('Morocco', Decimal('121.350000')),
#  ('Mozambique', Decimal('14.030000')),
#  ('Myanmar', Decimal('78.930000')),
#  ('Namibia', Decimal('10.580000')),
#  ('Nauru', Decimal('0.110000')),
#  ('Nepal', Decimal('33.430000')),
#  ('New Caledonia', Decimal('9.440000')),
#  ('New Zealand', Decimal('211.730000')),
#  ('Nicaragua', Decimal('12.590000')),
#  ('Niger', Decimal('13.740000')),
#  ('Nigeria', Decimal('432.200000')),
#  ('Niue', None),
#  ('Northern Mariana Islands', None),
#  ('Oman', Decimal('75.910000')),
#  ('Pakistan', Decimal('300.430000')),
#  ('Palau', Decimal('0.250000')),
#  ('Panama', Decimal('53.980000')),
#  ('Papua New Guinea', Decimal('23.850000')),
#  ('Paraguay', Decimal('35.430000')),
#  ('Peru', Decimal('201.710000')),
#  ('Philippines', Decimal('361.750000')),
#  ('Puerto Rico', Decimal('103.020000')),
#  ('Qatar', Decimal('144.410000')),
#  ('Republic of Korea', None),
#  ('Réunion', None),
#  ('Rwanda', Decimal('10.180000')),
#  ('Saint Barthélemy', None),
#  ('Saint Helena', None),
#  ('Saint Lucia', None),
#  ('Saint Martin (French Part)', None),
#  ('Saint Pierre and Miquelon', None),
#  ('Samoa', Decimal('0.870000')),
#  ('Sao Tome and Principe', Decimal('0.470000')),
#  ('Saudi Arabia', Decimal('703.370000')),
#  ('Senegal', Decimal('24.490000')),
#  ('Sierra Leone', Decimal('4.060000')),
#  ('Singapore', Decimal('345.300000')),
#  ('Solomon Islands', Decimal('1.540000')),
#  ('Somalia', Decimal('6.880000')),
#  ('South Africa', Decimal('337.620000')),
#  ('South Sudan', None),
#  ('Sri Lanka', Decimal('85.350000')),
#  ('State of Palestine', None),
#  ('Sudan', Decimal('27.030000')),
#  ('Suriname', Decimal('2.910000')),
#  ('Syrian Arab Republic', Decimal('11.080000')),
#  ('Tajikistan', Decimal('8.130000')),
#  ('Thailand', Decimal('499.680000')),
#  ('Timor-Leste', Decimal('2.160000')),
#  ('Togo', Decimal('7.570000')),
#  ('Tokelau', None),
#  ('Tonga', Decimal('0.480000')),
#  ('Trinidad and Tobago', Decimal('21.060000')),
#  ('Tunisia', Decimal('42.540000')),
#  ('Türkiye', None),
#  ('Turkmenistan', None),
#  ('Tuvalu', Decimal('0.060000')),
#  ('Uganda', Decimal('37.600000')),
#  ('United Arab Emirates', Decimal('349.470000')),
#  ('United Republic of Tanzania', None),
#  ('United States of America', None),
#  ('United States Virgin Islands', None),
#  ('Uruguay', Decimal('53.560000')),
#  ('Uzbekistan', Decimal('59.890000')),
#  ('Vanuatu', Decimal('0.900000')),
#  ('Venezuela (Bolivarian Republic of)', None),
#  ('Viet Nam', None),
#  ('Wallis and Futuna Islands', None),
#  ('Yemen', None),
#  ('Zambia', Decimal('18.110000')),
#  ('Zimbabwe', Decimal('21.510000'))]

# %% [markdown]
# ### Task 2

# %% [markdown]
# In order to answer our question, we need to pull data from both the Economic_Indicators and the Basic_Services tables; therefore, we need to join them together. Using `Country_name` and  `Time_period`, join the Basic_Services table to the Economic_Indicators table.

# %%
# %%sql
# # Add your code here
# SELECT
#     atbs.Country_name,
#     atbs.Est_gdp_in_billions,
#     atbs.Est_population_in_millions
# FROM Access_to_Basic_Services AS atbs
# JOIN
#     Economic_Indicators ei
# ON
#     atbs.Country_name = ei.Country_name
#     AND atbs.Time_period = ei.Time_period
# WHERE atbs.Time_period = 2020
# GROUP BY atbs.Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 165 rows affected.
# [('Afghanistan', Decimal('20.14'), Decimal('38.972230')),
#  ('Algeria', Decimal('145.01'), Decimal('43.451666')),
#  ('American Samoa', Decimal('0.72'), Decimal('0.046189')),
#  ('Angola', Decimal('53.62'), Decimal('33.428486')),
#  ('Argentina', Decimal('385.54'), Decimal('45.376763')),
#  ('Armenia', Decimal('12.64'), Decimal('2.805608')),
#  ('Australia', Decimal('1326.90'), Decimal('25.655289')),
#  ('Azerbaijan', Decimal('42.69'), Decimal('10.093121')),
#  ('Bahrain', Decimal('34.72'), Decimal('1.477469')),
#  ('Bangladesh', Decimal('373.90'), Decimal('167.420951')),
#  ('Barbados', Decimal('4.67'), Decimal('0.280693')),
#  ('Belize', Decimal('2.08'), Decimal('0.394921')),
#  ('Benin', Decimal('15.65'), Decimal('12.643123')),
#  ('Bermuda', Decimal('6.89'), Decimal('0.063893')),
#  ('Bhutan', Decimal('2.33'), Decimal('0.772506')),
#  ('Bolivia (Plurinational State of)', None, None),
#  ('Botswana', Decimal('14.93'), Decimal('2.546402')),
#  ('Brazil', Decimal('1448.56'), Decimal('213.196304')),
#  ('British Virgin Islands', None, Decimal('0.030910')),
#  ('Brunei Darussalam', Decimal('12.01'), Decimal('0.441725')),
#  ('Burkina Faso', Decimal('17.93'), Decimal('21.522626')),
#  ('Burundi', Decimal('2.65'), Decimal('12.220227')),
#  ('Cabo Verde', Decimal('1.70'), Decimal('0.582640')),
#  ('Cambodia', Decimal('25.87'), Decimal('16.396860')),
#  ('Cameroon', Decimal('40.77'), Decimal('26.491087')),
#  ('Canada', Decimal('1645.42'), Decimal('38.037204')),
#  ('Central African Republic', Decimal('2.33'), Decimal('5.343020')),
#  ('Chad', Decimal('10.72'), Decimal('16.644701')),
#  ('Chile', Decimal('252.73'), Decimal('19.300315')),
#  ('China', Decimal('14687.67'), Decimal('1411.100000')),
#  ('Colombia', Decimal('270.30'), Decimal('50.930662')),
#  ('Congo', None, None),
#  ('Cook Islands', None, None),
#  ('Costa Rica', Decimal('62.16'), Decimal('5.123105')),
#  ("Côte d'Ivoire", None, None),
#  ('Cuba', Decimal('107.35'), Decimal('11.300698')),
#  ('Cyprus', Decimal('25.01'), Decimal('1.237537')),
#  ("Democratic People's Republic of Korea", None, None),
#  ('Democratic Republic of the Congo', None, None),
#  ('Djibouti', Decimal('3.18'), Decimal('1.090156')),
#  ('Dominican Republic', Decimal('78.84'), Decimal('10.999664')),
#  ('Ecuador', Decimal('99.29'), Decimal('17.588595')),
#  ('Egypt', None, None),
#  ('El Salvador', Decimal('24.56'), Decimal('6.292731')),
#  ('Eswatini', Decimal('3.98'), Decimal('1.180655')),
#  ('Ethiopia', Decimal('107.66'), Decimal('117.190911')),
#  ('Falkland Islands (Malvinas)', None, None),
#  ('Fiji', Decimal('4.48'), Decimal('0.920422')),
#  ('French Guiana', None, None),
#  ('French Polynesia', Decimal('5.71'), Decimal('0.301920')),
#  ('Gabon', Decimal('15.31'), Decimal('2.292573')),
#  ('Gambia', None, None),
#  ('Georgia', Decimal('15.84'), Decimal('3.722716')),
#  ('Ghana', Decimal('70.04'), Decimal('32.180401')),
#  ('Greenland', Decimal('3.08'), Decimal('0.056367')),
#  ('Guadeloupe', None, None),
#  ('Guam', Decimal('5.89'), Decimal('0.169231')),
#  ('Guatemala', Decimal('77.63'), Decimal('16.858333')),
#  ('Guinea', Decimal('14.18'), Decimal('13.205153')),
#  ('Guinea-Bissau', Decimal('1.43'), Decimal('2.015828')),
#  ('Guyana', Decimal('5.47'), Decimal('0.797202')),
#  ('Haiti', Decimal('14.51'), Decimal('11.306801')),
#  ('Honduras', Decimal('23.83'), Decimal('10.121763')),
#  ('India', Decimal('2667.69'), Decimal('1396.387127')),
#  ('Indonesia', Decimal('1058.69'), Decimal('271.857970')),
#  ('Iran (Islamic Republic of)', None, None),
#  ('Iraq', Decimal('184.37'), Decimal('42.556984')),
#  ('Israel', Decimal('413.27'), Decimal('9.215100')),
#  ('Jamaica', Decimal('13.81'), Decimal('2.820436')),
#  ('Japan', Decimal('5040.11'), Decimal('126.261000')),
#  ('Jordan', Decimal('44.18'), Decimal('10.928721')),
#  ('Kazakhstan', Decimal('171.08'), Decimal('18.755666')),
#  ('Kenya', Decimal('100.67'), Decimal('51.985780')),
#  ('Kiribati', Decimal('0.18'), Decimal('0.126463')),
#  ('Kuwait', Decimal('105.96'), Decimal('4.360444')),
#  ('Kyrgyzstan', None, None),
#  ("Lao People's Democratic Republic", None, None),
#  ('Lebanon', Decimal('31.71'), Decimal('5.662923')),
#  ('Lesotho', Decimal('2.23'), Decimal('2.254100')),
#  ('Liberia', Decimal('3.04'), Decimal('5.087584')),
#  ('Libya', Decimal('50.36'), Decimal('6.653942')),
#  ('Madagascar', Decimal('13.05'), Decimal('28.225177')),
#  ('Malawi', Decimal('12.18'), Decimal('19.377061')),
#  ('Malaysia', Decimal('337.34'), Decimal('33.199993')),
#  ('Maldives', Decimal('3.75'), Decimal('0.514438')),
#  ('Mali', Decimal('17.47'), Decimal('21.224040')),
#  ('Marshall Islands', Decimal('0.24'), Decimal('0.043413')),
#  ('Martinique', None, None),
#  ('Mauritania', Decimal('8.41'), Decimal('4.498604')),
#  ('Mauritius', Decimal('11.40'), Decimal('1.265740')),
#  ('Mayotte', None, None),
#  ('Mexico', Decimal('1090.52'), Decimal('125.998302')),
#  ('Mongolia', Decimal('13.31'), Decimal('3.294335')),
#  ('Montserrat', None, None),
#  ('Morocco', Decimal('121.35'), Decimal('36.688772')),
#  ('Mozambique', Decimal('14.03'), Decimal('31.178239')),
#  ('Myanmar', Decimal('78.93'), Decimal('53.423198')),
#  ('Namibia', Decimal('10.58'), Decimal('2.489098')),
#  ('Nauru', Decimal('0.11'), Decimal('0.012315')),
#  ('Nepal', Decimal('33.43'), Decimal('29.348627')),
#  ('New Caledonia', Decimal('9.44'), Decimal('0.271130')),
#  ('New Zealand', Decimal('211.73'), Decimal('5.090200')),
#  ('Nicaragua', Decimal('12.59'), Decimal('6.755895')),
#  ('Niger', Decimal('13.74'), Decimal('24.333639')),
#  ('Nigeria', Decimal('432.20'), Decimal('208.327405')),
#  ('Niue', None, None),
#  ('Northern Mariana Islands', None, Decimal('0.049587')),
#  ('Oman', Decimal('75.91'), Decimal('4.543399')),
#  ('Pakistan', Decimal('300.43'), Decimal('227.196741')),
#  ('Palau', Decimal('0.25'), Decimal('0.017972')),
#  ('Panama', Decimal('53.98'), Decimal('4.294396')),
#  ('Papua New Guinea', Decimal('23.85'), Decimal('9.749640')),
#  ('Paraguay', Decimal('35.43'), Decimal('6.618695')),
#  ('Peru', Decimal('201.71'), Decimal('33.304756')),
#  ('Philippines', Decimal('361.75'), Decimal('112.190977')),
#  ('Puerto Rico', Decimal('103.02'), Decimal('3.281538')),
#  ('Qatar', Decimal('144.41'), Decimal('2.760385')),
#  ('Republic of Korea', None, None),
#  ('Réunion', None, None),
#  ('Rwanda', Decimal('10.18'), Decimal('13.146362')),
#  ('Saint Barthélemy', None, None),
#  ('Saint Helena', None, None),
#  ('Saint Lucia', None, None),
#  ('Saint Martin (French Part)', None, None),
#  ('Saint Pierre and Miquelon', None, None),
#  ('Samoa', Decimal('0.87'), Decimal('0.214929')),
#  ('Sao Tome and Principe', Decimal('0.47'), Decimal('0.218641')),
#  ('Saudi Arabia', Decimal('703.37'), Decimal('35.997107')),
#  ('Senegal', Decimal('24.49'), Decimal('16.436120')),
#  ('Sierra Leone', Decimal('4.06'), Decimal('8.233970')),
#  ('Singapore', Decimal('345.30'), Decimal('5.685807')),
#  ('Solomon Islands', Decimal('1.54'), Decimal('0.691191')),
#  ('Somalia', Decimal('6.88'), Decimal('16.537016')),
#  ('South Africa', Decimal('337.62'), Decimal('58.801927')),
#  ('South Sudan', None, Decimal('10.606227')),
#  ('Sri Lanka', Decimal('85.35'), Decimal('21.919000')),
#  ('State of Palestine', None, None),
#  ('Sudan', Decimal('27.03'), Decimal('44.440486')),
#  ('Suriname', Decimal('2.91'), Decimal('0.607065')),
#  ('Syrian Arab Republic', Decimal('11.08'), Decimal('20.772595')),
#  ('Tajikistan', Decimal('8.13'), Decimal('9.543207')),
#  ('Thailand', Decimal('499.68'), Decimal('71.475664')),
#  ('Timor-Leste', Decimal('2.16'), Decimal('1.299995')),
#  ('Togo', Decimal('7.57'), Decimal('8.442580')),
#  ('Tokelau', None, None),
#  ('Tonga', Decimal('0.48'), Decimal('0.105254')),
#  ('Trinidad and Tobago', Decimal('21.06'), Decimal('1.518147')),
#  ('Tunisia', Decimal('42.54'), Decimal('12.161723')),
#  ('Türkiye', None, None),
#  ('Turkmenistan', None, Decimal('6.250438')),
#  ('Tuvalu', Decimal('0.06'), Decimal('0.011069')),
#  ('Uganda', Decimal('37.60'), Decimal('44.404611')),
#  ('United Arab Emirates', Decimal('349.47'), Decimal('9.287289')),
#  ('United Republic of Tanzania', None, None),
#  ('United States of America', None, None),
#  ('United States Virgin Islands', None, None),
#  ('Uruguay', Decimal('53.56'), Decimal('3.429086')),
#  ('Uzbekistan', Decimal('59.89'), Decimal('34.232050')),
#  ('Vanuatu', Decimal('0.90'), Decimal('0.311685')),
#  ('Venezuela (Bolivarian Republic of)', None, None),
#  ('Viet Nam', None, None),
#  ('Wallis and Futuna Islands', None, None),
#  ('Yemen', None, None),
#  ('Zambia', Decimal('18.11'), Decimal('18.927715')),
#  ('Zimbabwe', Decimal('21.51'), Decimal('15.669666'))]

# %% [markdown]
# ### Task 3
#
# Using the query created in Task 2, filter the results to display records where:
#
# 1. The year = 2020.
# 2. The GDP is above the global average.
# 3. Less than 90% of the country's population have access to managed drinking water services.
#
# Hint: Keep in mind that we determined the GDP above the global average in Task 1.

# %%
# %%sql
# # Add your code here
# SELECT
#     atbs.Country_name,
#     atbs.Est_gdp_in_billions,
#     atbs.Est_population_in_millions
# FROM
#     Access_to_Basic_Services AS atbs
# JOIN
#     Economic_Indicators ei
# ON
#     atbs.Country_name = ei.Country_name
#     AND atbs.Time_period = ei.Time_period
# WHERE
#     ei.Time_period = 2020
#     AND atbs.Pct_access_to_water < 90
#     AND ei.Est_gdp_in_billions > (
#         SELECT
#             AVG(Est_gdp_in_billions)
#         FROM
#             Economic_Indicators
#         WHERE
#             Time_period = 2020
#     )
# GROUP BY
#     atbs.Country_name;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 1 rows affected.
# [('Nigeria', Decimal('432.20'), Decimal('208.327405'))]

# %% [markdown]
# ## Solutions

# %% [markdown]
# ### Task 1

# %%
# %%sql
#
# SELECT
#     AVG(Est_gdp_in_billions)
# FROM
#     Economic_Indicators
# WHERE
#     Time_period = 2020;

# %% [markdown]
# ### Task 2

# %%
# %%sql
#
# SELECT
#     econ.Country_name,
#     econ.Time_period,
#     econ.Est_gdp_in_billions,
#     service.Pct_managed_drinking_water_services
# FROM
#     Economic_Indicators AS econ
# INNER JOIN
#     Basic_Services AS service
# ON
#     econ.Country_name = service.Country_name
#     AND econ.Time_period = service.Time_period
# LIMIT 10;

# %% [markdown]
# ### Task 3

# %%
# %%sql
#
# SELECT
#     econ.Country_name,
#     econ.Time_period,
#     econ.Est_gdp_in_billions,
#     service.Pct_managed_drinking_water_services
# FROM
#     Economic_Indicators AS econ
# INNER JOIN
#     Basic_Services AS service
# ON
#     econ.Country_name = service.Country_name
#     AND econ.Time_period = service.Time_period
# WHERE
#     econ.time_period = 2020
#     AND service.Pct_managed_drinking_water_services < 90
#     AND econ.Est_gdp_in_billions > (SELECT
#                                         AVG(Est_gdp_in_billions)
#                                     FROM
#                                         Economic_Indicators
#                                     WHERE
#                                         Time_period = 2020);

# %% [markdown]
# ## Summary

# %% [markdown]
# This layered query first calculates the average GDP and then uses that value to filter out countries, along with all of the other criteria.
# Nigeria is the only country that satisfies this criteria. While its GDP might be above average, the low access to water is linked to policies that are not aligned with SDG 6, bad governance, infrastructure, quality, and supply, according to the World Bank.
# Finally, note that these queries quickly become complex when we use JOINs, subqueries, filters, and calculations together. The code is hard to read now and will be even harder to read for someone else who might work on this later. So we need to be mindful of this as we create these complex queries.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:100px"  ;/>
# </div>
